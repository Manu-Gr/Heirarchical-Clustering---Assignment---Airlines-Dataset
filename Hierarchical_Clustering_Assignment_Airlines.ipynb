# %% [markdown]
# <a href="https://colab.research.google.com/github/Manu-Gr/Heirarchical-Clustering---Assignment---Airlines-Dataset/blob/main/Hierarchical_Clustering_Assignment_Airlines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Perform clustering (Hierarchical) for the airlines data to obtain optimum number of clusters.

# %%
# import hierarchical clustering libraries
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import normalize

# %%
#Read the dataset

airlines = pd.read_csv('EastWestAirlines(1).csv')
airlines
# Out:
#        ID#  Balance  Qual_miles  ...  Flight_trans_12  Days_since_enroll  Award?
# 0        1    28143           0  ...                0               7000       0
# 1        2    19244           0  ...                0               6968       0
# 2        3    41354           0  ...                0               7034       0
# 3        4    14776           0  ...                0               6952       0
# 4        5    97752           0  ...                4               6935       1
# ...    ...      ...         ...  ...              ...                ...     ...
# 3994  4017    18476           0  ...                1               1403       1
# 3995  4018    64385           0  ...                0               1395       1
# 3996  4019    73597           0  ...                0               1402       1
# 3997  4020    54899           0  ...                1               1401       0
# 3998  4021     3016           0  ...                0               1398       0
#
# ...

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airlines2 = airlines.drop(['ID#'],axis=1)
airlines2
# Out:
#       Balance  Qual_miles  ...  Days_since_enroll  Award?
# 0       28143           0  ...               7000       0
# 1       19244           0  ...               6968       0
# 2       41354           0  ...               7034       0
# 3       14776           0  ...               6952       0
# 4       97752           0  ...               6935       1
# ...       ...         ...  ...                ...     ...
# 3994    18476           0  ...               1403       1
# 3995    64385           0  ...               1395       1
# 3996    73597           0  ...               1402       1
# 3997    54899           0  ...               1401       0
# 3998     3016           0  ...               1398       0
#
# [3999 rows x 11 columns]

# %%
# Normalization function 
air2_norm =pd.DataFrame(normalize(airlines2),columns=airlines2.columns)
air2_norm
# Out:
#        Balance  Qual_miles  ...  Days_since_enroll    Award?
# 0     0.970414         0.0  ...           0.241371  0.000000
# 1     0.940209         0.0  ...           0.340437  0.000000
# 2     0.981113         0.0  ...           0.166880  0.000000
# 3     0.904428         0.0  ...           0.425527  0.000000
# 4     0.912226         0.0  ...           0.064718  0.000009
# ...        ...         ...  ...                ...       ...
# 3994  0.905810         0.0  ...           0.068784  0.000049
# 3995  0.999649         0.0  ...           0.021659  0.000016
# 3996  0.944948         0.0  ...           0.018001  0.000013
# 3997  0.999592         0.0  ...           0.025509  0.000000
# 3998  0.907271         0.0  ...           0.420546  0.000000
#
# [3999 rows x 11 columns]

# %%
# create dendrogram
dendrogram = sch.dendrogram(sch.linkage(air2_norm, method='complete'))

# %%
# create clusters
hclusters = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'ward')
hclusters
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
y=pd.DataFrame(hclusters.fit_predict(air2_norm),columns=['clustersid'])
y['clustersid'].value_counts()
# Out:
# 2    1547
# 4    1191
# 3     579
# 1     453
# 0     229
# Name: clustersid, dtype: int64

# %%
# Adding clusters to dataset
airlines2['clustersid']=hclusters.labels_
airlines2
# Out:
#       Balance  Qual_miles  cc1_miles  ...  Days_since_enroll  Award?  clustersid
# 0       28143           0          1  ...               7000       0           4
# 1       19244           0          1  ...               6968       0           2
# 2       41354           0          1  ...               7034       0           2
# 3       14776           0          1  ...               6952       0           2
# 4       97752           0          4  ...               6935       1           3
# ...       ...         ...        ...  ...                ...     ...         ...
# 3994    18476           0          1  ...               1403       1           3
# 3995    64385           0          1  ...               1395       1           4
# 3996    73597           0          3  ...               1402       1           2
# 3997    54899           0          1  ...               1401       0           4
# 3998     3016           0          1  ...               1398       0           2
#
# ...

# %%
# Group data by Clusters (K=5)
airlines2.groupby('clustersid').agg(['mean']).reset_index()
# Out:
#   clustersid       Balance  ... Days_since_enroll    Award?
#                       mean  ...              mean      mean
# 0          0   5524.222707  ...       4875.301310  0.131004
# 1          1  31066.514349  ...       4205.624724  0.858720
# 2          2  81201.080802  ...       4285.891403  0.312217
# 3          3  69569.894646  ...       4090.832470  0.525043
# 4          4  94957.590260  ...       3736.071369  0.230898
#
# [5 rows x 12 columns]

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(airlines2['clustersid'],airlines2['Balance'], c=hclusters.labels_)
